# %% [markdown]
# <a href="https://colab.research.google.com/github/leilaamani/Machine-learning/blob/main/matplotlib%26seaborn_library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
AI_df=pd.read_csv('/content/AI Li-ion battery ML (1).csv')
AI_df
# Out:
#           Algorithm  RMSE   MAE
# 0       ARNS-BiLSTM  1.80  0.85
# 1        ATAGA-BPNN  2.67  3.71
# 2         BiLSTM-AN  1.31  0.44
# 3             CNARX  1.20  3.90
# 4     CNN-BiLSTM-AM  0.48  0.30
# 5       CNN-LSTM-AL  0.43  0.32
# 6            CNN-TM  0.55  0.44
# 7         DCNN-LSTM  0.39  0.22
# 8         DELM-ISSA  1.01  1.03
# 9        DRNN-SWPSO  1.20  0.70
# 10             DRRN  1.73  1.24
# 11  Encoder-decoder  0.98  0.77
# 12          GA-BPNN  2.95  2.08
# 13              GAN  0.68  0.56
# 14         GRNN-QGA  0.36  0.30
# 15          GRU-CNN  0.92  1.03
# 16            GRUNN  0.58  0.47
# 17        IPSO-BPNN  0.78  1.01
# 18           IRBFNN  0.90  0.71
# 19         LSTM-DTV  1.30  1.30
# 20          LSTM-NN  0.53  0.38
# 21          LSTM-NN  1.41  0.47
# 22         LSTM-RNN  0.83  0.63
# 23        RCFE-NAHL  0.40  2.08
# 24            TCMNN  1.14  1.93
# 25           TL-DNN  0.92  0.89

# %%
AI_df['RMSE'].value_counts().plot(kind='bar')
plt.show()

# %%
plt.hist(AI_df['RMSE'])
# Out:
# (array([8., 3., 5., 5., 1., 2., 0., 0., 1., 1.]),
#  array([0.36 , 0.619, 0.878, 1.137, 1.396, 1.655, 1.914, 2.173, 2.432,
#         2.691, 2.95 ]),
#  <BarContainer object of 10 artists>)

# %%
# Algorithm=np.array([ARNS-BiLSTM,ATAGA-BPNN,BiLSTM-AN,CNARX,CNN-BiLSTM-AM,CNN-LSTM-AL,CNN-TM,DCNN-LSTM,DELM-ISSA,DRNN-SWPSO,DRRN,
#            Encoder-decoder,GA-BPNN,GAN,GRNN-QGA,GRU-CNN,GRUNN,IPSO-BPNN,IRBFNN,LSTM-DTV,LSTM-NN,LSTM-NN,LSTM-RNN,RCFE-NAHL,
#            TCMNN,TL-DNN])
# # RMSE=np.array([1.8,2.67,1.31,1.2,0.48,0.43,0.55,0.39,1.01,1.2,1.73,0.98,2.95,0.68,0.36,0.92,0.58,0.78,0.9,1.3,0.53,1.410.83,0.4,1.14,0.92])
# # MAE=[0.85,3.71,0.44,3.9,0.3,0.32,0.44,0.22,1.03,0.7,1.24,0.77,2.08,0.56,0.3,1.03,0.47,1.01,0.71,1.3,0.38,0.47,0.63,2.08,1.93,
#      0.89]
# rmse=np.array([AI_df.RMSE])
# plt.scatter(Algorithm,rmse)
# # plt.bar(Algorithm,RMSE)

# %%
mae=np.array([AI_df.MAE])
mae
# Out:
# array([[0.85, 3.71, 0.44, 3.9 , 0.3 , 0.32, 0.44, 0.22, 1.03, 0.7 , 1.24,
#         0.77, 2.08, 0.56, 0.3 , 1.03, 0.47, 1.01, 0.71, 1.3 , 0.38, 0.47,
#         0.63, 2.08, 1.93, 0.89]])

# %%
rmse=np.array([AI_df.RMSE])
rmse
# Out:
# array([[1.8 , 2.67, 1.31, 1.2 , 0.48, 0.43, 0.55, 0.39, 1.01, 1.2 , 1.73,
#         0.98, 2.95, 0.68, 0.36, 0.92, 0.58, 0.78, 0.9 , 1.3 , 0.53, 1.41,
#         0.83, 0.4 , 1.14, 0.92]])

# %%
algorithm=np.array([AI_df.Algorithm])
algorithm
# Out:
# array([['ARNS-BiLSTM', 'ATAGA-BPNN', 'BiLSTM-AN', 'CNARX',
#         'CNN-BiLSTM-AM', 'CNN-LSTM-AL', 'CNN-TM', 'DCNN-LSTM',
#         'DELM-ISSA', 'DRNN-SWPSO', 'DRRN', 'Encoder-decoder', 'GA-BPNN',
#         'GAN', 'GRNN-QGA', 'GRU-CNN', 'GRUNN', 'IPSO-BPNN', 'IRBFNN',
#         'LSTM-DTV', 'LSTM-NN', 'LSTM-NN', 'LSTM-RNN', 'RCFE-NAHL',
#         'TCMNN', 'TL-DNN']], dtype=object)

# %%
plt.scatter(mae,rmse)
plt.xlabel('MAE')
plt.ylabel('RMSE')
plt.show()

# %%
x=np.linspace(0,10,10)
x
# Out:
# array([ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#         5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ])

# %%
y=np.sqrt(x)
y
# Out:
# array([0.        , 1.05409255, 1.49071198, 1.82574186, 2.10818511,
#        2.3570226 , 2.5819889 , 2.78886676, 2.98142397, 3.16227766])

# %%
fig=plt.figure(figsize=(10,6),dpi=300)
axes1=fig.add_axes([0,0,0.7,0.7])
axes1.plot(x,x,label='x')
axes1.set_xlabel('X')
axes1.set_ylabel('Y')
axes2=fig.add_axes([0.04,0.37,0.3,0.3])
axes2.plot(x,x**2,label='x**2--')
axes2.set_xlabel('X')
axes2.set_ylabel('X**2')
# Out:
# Text(0, 0.5, 'X**2')

# %%
x=np.linspace(0,4,10)
y=x*1.5
plt.scatter(x,y)

# %%
x=np.random.randn(100)
plt.hist(x,bins=20)
plt.show()

# %%
iris_df=sns.load_dataset('iris')
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_df.sepal_length=iris_df.sepal_length.astype(np.float16)
iris_df.sepal_width=iris_df.sepal_width.astype(np.float16)
iris_df.petal_length=iris_df.petal_length.astype(np.float16)
iris_df.petal_length=iris_df.petal_length.astype(np.float16)
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float16
#  1   sepal_width   150 non-null    float16
#  2   petal_length  150 non-null    float16
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float16(3), float64(1), object(1)
# memory usage: 3.3+ KB

# %%
cor=iris_df.corr()
cor
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117620      0.871765     0.817941
# sepal_width      -0.117620     1.000000     -0.428408    -0.366087
# petal_length      0.871765    -0.428408      1.000000     0.962870
# petal_width       0.817941    -0.366087      0.962870     1.000000

# %%
sns.heatmap(cor,annot=True,cmap='coolwarm',linewidths=1)
# Out:
# <Axes: >

# %%
sns.pairplot(iris_df)

# %%
sns.pairplot(iris_df,hue='species')
